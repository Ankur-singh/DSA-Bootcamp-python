# %% [markdown]
# [Video Link](https://youtu.be/lhELGQAV4gg)

# %% [markdown]
# 1. Input a year and find whether it is a leap year or not.

# %%
def is_leap_year(year):
    if (year % 4 == 0) and not(year % 100 == 0):
        return True
    elif (year % 400 == 0):
        return True
    return False

print(is_leap_year(2000))
print(is_leap_year(2400))
print(is_leap_year(1800))
print(is_leap_year(1900))
print(is_leap_year(2023))
# Out:
# True
# True
# False
# False
# False

# %% [markdown]
# 2. Take two numbers and print the sum of both.

# %%
def add(a,b): return a+b

print(add(5,7))
print(add(1,2))
print(add(4,7))
print(add(5,2))
# Out:
# 12
# 3
# 11
# 7

# %% [markdown]
# 3. Take a number as input and print the multiplication table for it.

# %%
def table(n):
    for i in range(1, 11):
        print(f"{n} x {i} = {n*i}")

table(10)
# Out:
# 10 x 1 = 10
# 10 x 2 = 20
# 10 x 3 = 30
# 10 x 4 = 40
# 10 x 5 = 50
# 10 x 6 = 60
# 10 x 7 = 70
# 10 x 8 = 80
# 10 x 9 = 90
# 10 x 10 = 100

# %% [markdown]
# 4. Take 2 numbers as inputs and find their HCF and LCM.

# %%
def calculate_hcf(n,m):
    # Eucledian Algorithm
    while m != 0:
        remainder = n % m
        n = m
        m = remainder
    return n

def calculate_lcm_and_hcf(n,m):
    hcf = calculate_hcf(n,m)
    lcm = (n * m) / hcf
    return int(lcm), hcf

calculate_lcm_and_hcf(36,44)
# Out:
# (396, 4)

# %% [markdown]
# 5. Keep taking numbers as inputs till the user enters ‘x’, after that print sum of all.

# %%
total = 0
while True:
    input_number = input()
    if input_number == "x":
        print(total)
        break
    total += int(input_number)
# Out:
# 12
